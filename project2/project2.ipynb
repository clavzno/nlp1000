# %% [markdown]
# # Project 2: Similarity Matrix and Language Clustering
# Submitted on _ _, 2025
#
# NLP1000 S17
# Group 12:
# | Member Name      | ID Number      |
# | ------------- | ------------- |
# | Alcantara, Van Asher | 12340898 |
# | Aragon, Enrique | 12227811 |
# | Clavano, Angelica (Jack) | 12206245 |
# | Lozada, Job | 12307246 |
#
# ## Table of Contents
# 1. Data Selection & Web Scraping
# 2. Data Cleaning and Segmentation
# 3. Parallel Corpus
#
# ---
#
# ## Running this Notebook:
# - Make sure you have at least Python 3.12.0 or 3.14.0 installed.
# - To install the requirements, run `pip install -r requirements.txt` It has been updated for usage with `project2.ipynb`
#
# ---
#
# ## Folder Structure:
# ```
# /nlp1000 --> root
# └── /data
#     └── lang.txt files --> raw webscraped data
#     └── /cleaned
#         └── (sentences)-lang-cleaned.txt --> cleaned sentence files in txt format
#         └── lang-cleaned.txt --> cleaned verse files in txt format
# └── /parallel-corpora --> parallel corpora (aligned) but in separate xlsx files
# └── .gitignore
# └── main.ipynb --> PROJECT 1 SUBMISSION containing documentation and source code
# └── project2.ipynb --> PROJECT 2 SUBMISSION
# └── removed.ipynb --> experimental code not part of the main submission
# └── cleaned_sentences.ipynb --> cleaned sentence files in xlsx format - from data/cleaned/(sentences)-(lang)-cleaned.txt files
# └── README.md --> contains the same information as this markdown block.
# └── cleaned_verses.xlsx --> cleaned verse files in xlsx format - created when running the notebook from data/cleaned/(lang)-cleaned.txt
# └── parallel_corpora.xlsx --> parallel corpora base file (unaligned) - created when running the notebook
# └── parallel_corpora_all.xlsx --> parallel corpora (aligned)
# └── ai_declaration_project1.pdf --> AI declaration
# └── ai_declaration_project2.pdf --> AI DECLARATION FOR PROJECT 2
# └── steps.xlsx --> steps for regex present in divide_into_verses() and divide_into_sentences()
# ```

# %% [markdown]
# ## 0. Libraries

# %%
import nltk                 # pip install nltk
from pathlib import Path    # pip install pathlib
import pandas as pd         # pip install pandas
import sklearn as sk        # pip install scikit-learn 
from nltk.tokenize import TweetTokenizer

# %%
# our main reference

languages = ["spanish", "tagalog", "english", "hiligaynon", "bikol", "waray", "ilocano", "cebuano", "kapampangan", "pangasinense", "yakan", "ivatan", "tausug", "yami", "tuwali_ifugao", "masbateno"]
bibleNumbers = ["1076", "177", "3523", "2190", "890", "2198", "782", "562", "1141", "2194", "1388", "1315", "1319", "2364", "2123", "1222"]
bibleAbbreviation = ["JBS", "TLAB", "NRSVUE", "MBBHIL12", "MBBBIK92", "MBBSAM", "RIPV", "RCPV", "PMPV", "MBBPAN83", "YAKV", "VTSP", "TSG", "SNT", "IFKWB", "MSB"]

bookCodes = ["mat", "mrk", "luk", "jhn"]
chapterRanges = {
    "mat": [1, 28],
    "mrk": [1, 16],
    "luk": [1, 24],
    "jhn": [1, 21]
}

# %%
#needed for nltk, you can just run this once
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('popular')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\gicac\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# ## 1. Data Sources, Preprocessing, and Feature Engineering

# %% [markdown]
# ### 1.1 Tokenizing

# %%
'''
# base code for accessing all files per language
# we're not using the old data folder we have a copy of it here in project2/
data_folder = Path("p2data")

# output file paths here
# raw_data_filepath = data_folder / f"{lang}.txt"
# all_verses_filepath = data_folder / f"{lang}-cleaned.txt"
# all_sentences_filepath = data_folder / f"(sentences)-{lang}-cleaned.txt"

for lang in languages: 
    output_file_path = # check above

    if if cleaned_file_path.exists() and cleaned_file_path.stat().st_size > 0:
        with cleaned_file_path.open("r", encoding="utf-8") as f:
        # do whatever you want here
            text = f.read()
            word_count = len(text.split())
            total_word_count += word_count
            print(f"Word count for {lang}.txt: {word_count}")

    else:
        print(f"Skipped: {cleaned_file_path} (file does not exist or is empty)")


for lang in languages:
    output_file_path = # check above

    if not source_file_path.exists() or source_file_path.stat().st_size == 0:
        print(f"Skipped: {source_file_path} (file does not exist or is empty)")
        continue
        
    # rewrite all the txts if it exists
    if output_file_path.exists():
        print(f"unlinking/deleting old files")
        output_path.unlink()

    # read input
    with source_file_path.open("r", errors="ignore", encoding="utf-8") as f:
        text = f.read()
    
    # do whatever you want here
    cleaned_text = something(text)

    # save it
    with output_path.open("w", encoding="utf-8") as f:
        f.write(cleaned_text)

    print(f"Cleaned and saved: {output_path}")'''
# Out:
# '\n# base code for accessing all files per language\n# we\'re not using the old data folder we have a copy of it here in project2/\ndata_folder = Path("p2data")\n\n# output file paths here\n# raw_data_filepath = data_folder / f"{lang}.txt"\n# all_verses_filepath = data_folder / f"{lang}-cleaned.txt"\n# all_sentences_filepath = data_folder / f"(sentences)-{lang}-cleaned.txt"\n\nfor lang in languages: \n    output_file_path = # check above\n\n    if if cleaned_file_path.exists() and cleaned_file_path.stat().st_size > 0:\n        with cleaned_file_path.open("r", encoding="utf-8") as f:\n        # do whatever you want here\n            text = f.read()\n            word_count = len(text.split())\n            total_word_count += word_count\n            print(f"Word count for {lang}.txt: {word_count}")\n\n    else:\n        print(f"Skipped: {cleaned_file_path} (file does not exist or is empty)")\n\n\nfor lang in languages:\n    output_file_path = # check above\n\n    if not source_file_path.exists() or source_file_path.stat().st_size == 0:\n        print(f"Skipped: {source_file_path} (file does not exist or is empty)")\n        continue\n\n    # rewrite all the txts if it exists\n    if output_file_path.exists():\n        print(f"unlinking/deleting old files")\n        output_path.unlink()\n\n    # read input\n    with source_file_path.open("r", errors="ignore", encoding="utf-8") as f:\n        text = f.read()\n\n    # do whatever you want here\n    cleaned_text = something(text)\n\n    # save it\n    with output_path.open("w", encoding="utf-8") as f:\n        f.write(cleaned_text)\n\n    print(f"Cleaned and saved: {output_path}")'

# %%
data_folder = Path("p2data")
tokenizer = TweetTokenizer(r'\w+')

for lang in languages:
    test = ""
    source_file_path = data_folder / f"(sentences)-{lang}-cleaned.txt"
    output_file_path = data_folder/f"(common-words)-{lang}.txt"

    # if it doesn't exist
    if not source_file_path.exists() or source_file_path.stat().st_size == 0:
        print(f"Skipped: {source_file_path} (file does not exist or is empty)")
        continue

    # rewrite all the txts if it exists
    if output_file_path.exists():
        print(f"unlinking/deleting old files")
        output_file_path.unlink()
    
    # read input
    with source_file_path.open("r", errors="ignore", encoding="utf-8") as f:
        raw_sentences = f.read()
    
    # do whatever you want here
    allWords = tokenizer.tokenize(raw_sentences)

    stopwords = ('.', ',', ';', '?', ':', '?', '(', ')', '"', '\'')
    allWordsFreq = nltk.FreqDist(w.lower() for w in allWords if w not in stopwords)
    for word, count in allWordsFreq.most_common(500):
        strCount = str(count)
        test = test + word+ ":" + strCount + "\n" 

    with output_file_path.open("w", encoding="utf-8") as f:
        f.write(test)

    print(f"Cleaned and saved: {output_file_path}")
# Out:
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-spanish.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-tagalog.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-english.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-hiligaynon.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-bikol.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-waray.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-ilocano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-cebuano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-kapampangan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-pangasinense.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-yakan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-ivatan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-tausug.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-yami.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-tuwali_ifugao.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(common-words)-masbateno.txt

# %% [markdown]
# ### 1.2 Using nltk to generate n-grams
#
# We'll be using nltk to generate the n-grams of all the languages we have. We'll save them into files per language.
#
# [Source for words](https://www.pythontutorials.net/nltk/how-to-create-ngrams-with-nltk/)
#
#
# [Source for characters](https://groups.google.com/g/nltk-users/c/9_dVwH4SBmc)

# %%
# sample code that turns bikol sentences into unigrams, bigrams, and trigrams
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

data_folder = Path("p2data")

for lang in languages:
    # define source and output
    source_file_path = data_folder / f"(sentences)-{lang}-cleaned.txt"
    output_file_path = data_folder/f"(trigrams)-{lang}.txt"

    # if source doesn't exist skip
    if not source_file_path.exists() or source_file_path.stat().st_size == 0:
            print(f"Skipped: {source_file_path} (file does not exist or is empty)")
            # continue
    else:       
        # rewrite all the txts if it exists
        if output_file_path.exists():
            print(f"unlinking/deleting old files")
            output_file_path.unlink()

        # read input
        with source_file_path.open("r", errors="ignore", encoding="utf-8") as f:
            raw_sentences = f.read()

        # DO WHATEVER YOU WANT HERE
        # tokens = word_tokenize(raw_sentences) # split into words - DON'T DELETE THIS THANKS
        characters = [c for c in raw_sentences]

        # if you want to do it in words replace "characters" with "tokens"
        # unigrams = list(ngrams(characters, 1))
        # bigrams = list(ngrams(characters, 2))
        trigrams = list(ngrams(characters, 3))

        # save them to the file
        with output_file_path.open("w", encoding="utf-8") as f:
            '''f.write("Unigrams\n")
            for list_tuple in unigrams:
                f.write(" ".join(map(str, list_tuple)) + "\n") 
            f.write("Bigrams\n")
            for list_tuple in bigrams:
                f.write(" ".join(map(str, list_tuple)) + "\n")'''
            f.write("Trigrams\n")
            for list_tuple in trigrams:
                # replace space with _ for readability and so the tab actually works in top 250
                cleaned = ( '_' if (isinstance(ch, str) and ch.isspace()) else str(ch) for ch in list_tuple )
                f.write("".join(cleaned) + "\n")
                # f.write(" ".join(map(str, list_tuple)) + "\n") - DONT DELETE THIS THANKS

        print(f"Cleaned and saved: {output_file_path}")
# Out:
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-spanish.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-tagalog.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-english.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-hiligaynon.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-bikol.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-waray.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-ilocano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-cebuano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-kapampangan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-pangasinense.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-yakan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-ivatan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-tausug.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-yami.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-tuwali_ifugao.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(trigrams)-masbateno.txt

# %% [markdown]
# Below, we'll be getting the frequency count of each character trigram per language. Then using the frequency count, we'll write the top 250 trigrams into another file.

# %%
from collections import Counter
data_folder = Path("p2data")

for lang in languages:
    # define source and output
    source_file_path = data_folder / f"(trigrams)-{lang}.txt"
    output_file_path = data_folder/f"(top250trigrams)-{lang}.txt"

    # if source doesn't exist skip
    if not source_file_path.exists() or source_file_path.stat().st_size == 0:
            print(f"Skipped: {source_file_path} (file does not exist or is empty)")
            # continue
    else:       
        # rewrite all the txts if it exists
        if output_file_path.exists():
            print(f"unlinking/deleting old files")
            output_file_path.unlink()

        # read input
        with source_file_path.open("r", errors="ignore", encoding="utf-8") as f:
            next(f, None) # skip the first line bc it's just a title
            trigrams = [line.strip() for line in f if line.strip()]

        # DO WHATEVER YOU WANT HERE
        freq_counter = Counter(trigrams)
        top_250 = freq_counter.most_common(250)

        # save them to the file
        with output_file_path.open("w", encoding="utf-8") as f:
            f.write("Top 250\tFrequency\n")
            for trigram, count in top_250:
                 f.write(f"{trigram}\t\t{count}\n")

        print(f"Cleaned and saved: {output_file_path}")
# Out:
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-spanish.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-tagalog.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-english.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-hiligaynon.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-bikol.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-waray.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-ilocano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-cebuano.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-kapampangan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-pangasinense.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-yakan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-ivatan.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-tausug.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-yami.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-tuwali_ifugao.txt
# unlinking/deleting old files
# Cleaned and saved: p2data\(top250trigrams)-masbateno.txt

# %% [markdown]
# ## 2. Similarity and Clustering / Dendrogram

# %% [markdown]
# Using the top 250 trigrams per language created in the previous section, we can now create the similarity matrix.
#
# [Source](https://spotintelligence.com/2022/12/19/text-similarity-python/#1_Text_similarity_with_NLTK)
#
# [Source](https://www.geeksforgeeks.org/machine-learning/understanding-tf-idf-term-frequency-inverse-document-frequency/)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def text_similarity(text1, text2):
    # placeholder
    tfidf = TfidfVectorizer()
    pass

# %% [markdown]
# <mark style="background-color:yellow">IGNORE THE THINGS ABOVE MUNA FOR THIS SECTION </mark>

# %%
data_folder = Path("p2data")

# import the top 250 trigrams sheet
top250csv_filepath = data_folder / "top250trigrams.csv"
top250_df = pd.read_csv(top250csv_filepath)

# set the cols to s1, s2, s3 etc.
cols = list(top250_df.columns)
top250_df.columns = [f"s{i+1}" for i in range(top250_df.shape[1])]
top250_df.head()
# Out:
#     s1   s2   s3   s4   s5   s6   s7   s8   s9  s10  s11  s12  s13  s14  s15  \
# 0  an_  an_  _a_  ng_  ti_  _ka  ng_  an_  in_  _si  an_  _th  ng_  _de  ng_
# 1  _na  _na  o_a  ang  iti  an_  ing  ay_  iya  si_  _sa  the  _sa  os_  ang
# 2  _sa  NaN  na_  sa_  _ti  _na  ang  _na  an_  an_  _na  he_  ang  que  _sa
# 3  na_  ya_  _na  _sa  _a_  _a_  an_  _to  _ma  _pa  ng_  nd_  ga_  ue_  _na
# 4  _ka  _di  an_  _ka  _it  a_a  _ka  _si  _si  ang  _ka  _an  sa_  de_  sa_
#
#    s16
# 0  an_
# 1  nga
# 2  _ng
# 3  _ha
# 4  ga_

# %%
# divide each one into a series
languages = ["masbateno", "tuwali_ifugao", "yami", "cebuano", "ilocano", "ivatan", "kapampangan", "pangasinense", "tausug", "yakan", "bikol", "english", "hiligaynon", "spanish", "tagalog", "waray"]

# order: Masbateno,Tuwali-Ifugao,Yami,Cebuano,Ilocano,Ivatan,Kapampangan,Pangasinense,Tausug,Yakan,Bikol,English,Hiligaynon,Spanish,Tagalog,Waray
series_list = [top250_df.iloc[:, i] for i in range(top250_df.shape[1])]

masbateno_df = series_list[0] # masbateno
tuwali_ifugao_df = series_list[1]
yami_df = series_list[2]
cebuano_df = series_list[3]
ilocano_df = series_list[4]
ivatan_df = series_list[5]
kapampangan_df = series_list[6]
pangasinense_df = series_list[7]
tausug_df = series_list[8]
yakan_df = series_list[9]
bikol_df = series_list[10]
english_df = series_list[11]
hiligaynon_df = series_list[12]
spanish_df = series_list[13]
tagalog_df = series_list[14]
waray_df = series_list[15]

# put them here just so its easier for everyone instead of doing series_list[i] a lot
all250series = [masbateno_df, tuwali_ifugao_df, yami_df, cebuano_df, ilocano_df, ivatan_df, kapampangan_df, pangasinense_df, tausug_df, yakan_df, bikol_df, english_df, hiligaynon_df, spanish_df, tagalog_df, waray_df]

for series in all250series:
    print(series.head())
# Out:
# 0    an_
# 1    _na
# 2    _sa
# 3    na_
# 4    _ka
# Name: s1, dtype: object
# 0    an_
# 1    _na
# 2    NaN
# 3    ya_
# 4    _di
# Name: s2, dtype: object
# 0    _a_
# 1    o_a
# 2    na_
# 3    _na
# 4    an_
# Name: s3, dtype: object
# 0    ng_
# 1    ang
# 2    sa_
# 3    _sa
# 4    _ka
# Name: s4, dtype: object
# 0    ti_
# 1    iti
# 2    _ti
# 3    _a_
# 4    _it
# Name: s5, dtype: object
# 0    _ka
# 1    an_
# 2    _na
# 3    _a_
# 4    a_a
# Name: s6, dtype: object
# 0    ng_
# 1    ing
# 2    ang
# 3    an_
# 4    _ka
# Name: s7, dtype: object
# 0    an_
# 1    ay_
# 2    _na
# 3    _to
# 4    _si
# Name: s8, dtype: object
# 0    in_
# 1    iya
# 2    an_
# 3    _ma
# 4    _si
# Name: s9, dtype: object
# 0    _si
# 1    si_
# 2    an_
# 3    _pa
# 4    ang
# Name: s10, dtype: object
# 0    an_
# 1    _sa
# 2    _na
# 3    ng_
# 4    _ka
# Name: s11, dtype: object
# 0    _th
# 1    the
# 2    he_
# 3    nd_
# 4    _an
# Name: s12, dtype: object
# 0    ng_
# 1    _sa
# 2    ang
# 3    ga_
# 4    sa_
# Name: s13, dtype: object
# 0    _de
# 1    os_
# 2    que
# 3    ue_
# 4    de_
# Name: s14, dtype: object
# 0    ng_
# 1    ang
# 2    _sa
# 3    _na
# 4    sa_
# Name: s15, dtype: object
# 0    an_
# 1    nga
# 2    _ng
# 3    _ha
# 4    ga_
# Name: s16, dtype: object

# %% [markdown]
# ## 3. Matrix and Tree Interpretation

# %% [markdown]
# ## 4. Conclusion and Limitations

# %% [markdown]
# ## Resources
